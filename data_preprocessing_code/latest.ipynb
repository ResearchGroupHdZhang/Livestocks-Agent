# %%
import pandas as pd 

# 导入数据
data = pd.read_csv("eurostat/animal_geo_ok/1980.csv")

# %%
# 查看数据
data.head()
# Out:
#   country country_label state    state_label county      county_label  \
# 0      AT       Austria   AT1  Ostösterreich   AT11   Burgenland (AT)
# 1      AT       Austria   AT1  Ostösterreich   AT12  Niederösterreich
# 2      AT       Austria   AT1  Ostösterreich   AT13              Wien
# 3      AT       Austria   AT2  Südösterreich   AT21           Kärnten
# 4      AT       Austria   AT2  Südösterreich   AT22        Steiermark
#
#                  unit_label  year  Dairy cows  Beef cattle  excl cattle  \
# 0  Thousand heads (animals)  1980         NaN          0.0          NaN
# 1  Thousand heads (animals)  1980         NaN          0.0          NaN
# 2  Thousand heads (animals)  1980         NaN          0.0          NaN
# 3  Thousand heads (animals)  1980         NaN          0.0          NaN
# 4  Thousand heads (animals)  1980         NaN          0.0          NaN
#
#    Fattening pigs, live weight 50 kg or over  Sheep  County Layers  \
# ...

# %%
bx_data = pd.read_excel("巴西/农作物_fao_ok/2022_.xlsx")

# %%
bx_data.head()
# Out:
#   Nível     Cód.                   Município Feijão (em grão)   花生 马铃薯  \
# 0    MU  1100015  Alta Floresta D'Oeste (RO)               480  ..  ..
# 1    MU  1100023              Ariquemes (RO)                 1  ..  ..
# 2    MU  1100031                 Cabixi (RO)               ...  ..  ..
# 3    MU  1100049                 Cacoal (RO)                60  ..  ..
# 4    MU  1100056             Cerejeiras (RO)                 3  ..  ..
#
#   Milho (em grão)  Abacaxi* Alfafa fenada Algodão herbáceo (em caroço)  ...  \
# 0             5556      100           ...                            -  ...
# 1            11400      416           ...                            -  ...
# 2            96948       55           ...                            -  ...
# 3             5280     1955           ...                            -  ...
# 4           138819      505           ...                            -  ...
#
#   Noz (fruto seco) Palmito Pera Pêssego Pimenta-do-reino  \
# ...

# %%
# 提取FAO巴西农作物数据
data = pd.read_csv('faostat_HGU/Production/Crops and livestock products/Production_Quantity/Crops_primary/2022.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 # 提取FAO巴西农作物数据
# ----> 2 data = pd.read_csv('faostat_HGU/Production/Crops and livestock products/Production_Quantity/Crops_primary/2022.csv')
#
# File d:\D盘文件夹\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File d:\D盘文件夹\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %%
new_data = data[data['Area']=='Brazil']

# %%
new_data.to_csv('校对总量全（新）/巴西/FAO/农作物/1974.csv', index=False)
