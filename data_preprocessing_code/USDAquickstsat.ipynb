# %%
import usda_quickstats as stat
import pandas as pd
import re
import matplotlib.pyplot as plt

# %%
stat.Key_init("7BF5BA5C-D7DA-356F-8412-A4710CAE3113")
# Out:
# API Key initialized successfully

# %%
plt.rcParams["font.sans-serif"] = ["simhei"]

# %% [markdown]
# # 数据下载

# %%
State = stat.get_par("state_name")

# %% [markdown]
# # 需要下载的数据有：
# ### 1、state:动物的poultry(program:survey)slaughtered，无inventory
# ### 2、state:动物的livestock(program:survey)slaughtered 无inv...
# ### 3、county:动物的poultry(program:census)inventory
# ### 4、county:动物的livestock(program:census)inventory

# %% [markdown]
# ## 下载第三个

# %%
# 下载county的动物的poultry,后续记得删除poultry total
# GROUP选择了poultry
params = {
    "source_desc":"CENSUS",
    "sector_desc":"ANIMALS & PRODUCTS",
    "group_desc":"POULTRY",
#     "commodity_desc":["CHICKENS","DUCKS","EGGS","MEAL","POULTRY BY-PRODUCT MEALS",
#                      "POULTRY FATS","POULTRY TOTALS","POULTRY, OTHER","TURKEYS"],
    "statisticcat_desc":["INVENTORY"],
#     "short_desc":["CHICKENS, YOUNG, SLAUGHTER, FI - SLAUGHTERED, MEASURED IN HEAD",
#                   "CHICKENS, YOUNG, SLAUGHTER, FI - SLAUGHTERED, MEASURED IN LB / HEAD, LIVE BASIS",
#                  "CHICKENS, YOUNG, SLAUGHTER, FI - SLAUGHTERED, MEASURED IN LB, LIVE BASIS",
#                  "TURKEYS, YOUNG, SLAUGHTER, FI - SLAUGHTERED, MEASURED IN HEAD",
#                   "TURKEYS, YOUNG, SLAUGHTER, FI - SLAUGHTERED, MEASURED IN LB / HEAD, LIVE BASIS",
#                  "TURKEYS, YOUNG, SLAUGHTER, FI - SLAUGHTERED, MEASURED IN LB, LIVE BASIS"],
    "agg_level_desc":"COUNTY",
}

# %%
stat.get_par(params)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 stat.get_par(params)
#
# File d:\usda_quickstats\usda_quickstats.py:114, in get_par(par)
#     112 else:
#     113     status = response.status_code
# --> 114     status_str='Response code ' + str(status) + ': ' + response.json()[par][0]
#     115     print(status_str)
#     116     return pd.DataFrame()
#
# TypeError: unhashable type: 'dict'

# %%
# 若总数据不大于5万，则一起下载
for year in range(1924,2023):
    params["year"]=str(year)
    data=stat.get_data(params)
    # 删除不要的列
    columns_to_drop = ["begin_code","load_time","end_code","congr_district_code"]
    data.drop(columns_to_drop, axis=1, inplace=True)
    data.to_csv("D:/中科院数据下载/quickstats/county/poultry/"+str(year)+".csv",index=False)

# %%
# data_all = pd.DataFrame()
# # 数据太多了，所以按照州的五个五个下载，再用python合并
# for i in range(0,State.shape[0],5):
#     last = min(State.shape[0],i+4)
#     params["state_name"] = list(State.loc[i:last].state_name)
#     data = stat.get_data(params)
#     print(data.shape[0])
    
#     # 将所有州合在一起，形成一个DF，最后再按照年划分
#     data_all = pd.concat([data_all,data],axis=0) # 按行合并
data_all = pd.DataFrame()
# 数据太多了，所以按照州的一个一个下载，再用python合并
for i in range(State.shape[0]):
    params["state_name"] = State.loc[i].state_name
    data = stat.get_data(params)
    print(str(State.loc[i].state_name)+":"+str(data.shape[0]))
    
    # 将所有州合在一起，形成一个DF，最后再按照年划分
    data_all = pd.concat([data_all,data],axis=0) # 按行合并
# Out:
# ALABAMA:6791
# ALASKA:453
# Response code 400: bad request - invalid query
# AMERICAN SAMOA:0
# ARIZONA:1578
# ARKANSAS:6729
# CALIFORNIA:6027
# COLORADO:5200
# CONNECTICUT:996
# DELAWARE:335
# FLORIDA:6702
# GEORGIA:11724
# Response code 400: bad request - invalid query
# GUAM:0
# HAWAII:410
# IDAHO:3746
# ILLINOIS:9147
# INDIANA:8491
# IOWA:9438
# KANSAS:8364
# KENTUCKY:10839
# LOUISIANA:4951
# MAINE:1664
# MARYLAND:2322
# MASSACHUSETTS:1385
# MICHIGAN:8546
# MINNESOTA:8447
# MISSISSIPPI:6414
# MISSOURI:11095
# MONTANA:4454
# NEBRASKA:7414
# NEVADA:1118
# Response code 400: bad request - invalid query
# NEW ENGLAND:0
# NEW HAMPSHIRE:1069
# NEW JERSEY:2194
# NEW MEXICO:2894
# NEW YORK:6179
# NORTH CAROLINA:9008
# NORTH DAKOTA:3524
# Response code 400: bad request - invalid query
# NORTHERN MARIANA ISLANDS:0
# OHIO:9517
# OKLAHOMA:7804
# OREGON:3826
# Response code 400: bad request - invalid query
# OTHER STATES:0
# PENNSYLVANIA:7915
# Response code 400: bad request - invalid query
# PUERTO RICO:0
# RHODE ISLAND:456
# SOUTH CAROLINA:4662
# SOUTH DAKOTA:4897
# TENNESSEE:9630
# TEXAS:22648
# Response code 400: bad request - invalid query
# US TOTAL:0
# UTAH:2589
# VERMONT:1395
# Response code 400: bad request - invalid query
# VIRGIN ISLANDS OF THE US:0
# VIRGINIA:8531
# WASHINGTON:4202
# WEST VIRGINIA:4627
# WISCONSIN:8056
# WYOMING:1993

# %%
all = 282396

# %%
data_all
# Out:
#      Program  year      Period    Period Type week_ending   country_name  \
# 0     CENSUS  2017  END OF DEC  POINT IN TIME              UNITED STATES
# 1     CENSUS  2012  END OF DEC  POINT IN TIME              UNITED STATES
# 2     CENSUS  2007  END OF DEC  POINT IN TIME              UNITED STATES
# 3     CENSUS  2002  END OF DEC  POINT IN TIME              UNITED STATES
# 4     CENSUS  1997  END OF DEC  POINT IN TIME              UNITED STATES
# ...      ...   ...         ...            ...         ...            ...
# 1988  CENSUS  1997  END OF DEC  POINT IN TIME              UNITED STATES
# 1989  CENSUS  2017  END OF DEC  POINT IN TIME              UNITED STATES
# 1990  CENSUS  2012  END OF DEC  POINT IN TIME              UNITED STATES
# 1991  CENSUS  2007  END OF DEC  POINT IN TIME              UNITED STATES
# 1992  CENSUS  2002  END OF DEC  POINT IN TIME              UNITED STATES
#
#      country_code state_ansi state_fips_code state_alpha  ...    Group  \
# 0            9000         01              01          AL  ...  POULTRY
# 1            9000         01              01          AL  ...  POULTRY
# 2            9000         01              01          AL  ...  POULTRY
# 3            9000         01              01          AL  ...  POULTRY
# 4            9000         01              01          AL  ...  POULTRY
# ...           ...        ...             ...         ...  ...      ...
# 1988         9000         56              56          WY  ...  POULTRY
# 1989         9000         56              56          WY  ...  POULTRY
# 1990         9000         56              56          WY  ...  POULTRY
# 1991         9000         56              56          WY  ...  POULTRY
# 1992         9000         56              56          WY  ...  POULTRY
#
#                                 Data Item Zip Code   class_desc      Value  \
# 0          CHICKENS, BROILERS - INVENTORY              BROILERS  1,094,358
# 1          CHICKENS, BROILERS - INVENTORY              BROILERS  1,871,616
# 2          CHICKENS, BROILERS - INVENTORY              BROILERS  1,670,490
# 3          CHICKENS, BROILERS - INVENTORY              BROILERS  1,846,500
# 4          CHICKENS, BROILERS - INVENTORY              BROILERS  1,282,775
# ...                                   ...      ...          ...        ...
# 1988  TURKEYS - OPERATIONS WITH INVENTORY           ALL CLASSES          4
# 1989  TURKEYS - OPERATIONS WITH INVENTORY           ALL CLASSES          3
# 1990  TURKEYS - OPERATIONS WITH INVENTORY           ALL CLASSES          5
# 1991  TURKEYS - OPERATIONS WITH INVENTORY           ALL CLASSES          1
# 1992  TURKEYS - OPERATIONS WITH INVENTORY           ALL CLASSES          1
#
#      CV (%) begin_code                load_time end_code congr_district_code
# 0      16.7         12  2018-02-01 00:00:00.000       12
# 1      26.4         12  2012-12-31 00:00:00.000       12
# 2                   12  2012-01-01 00:00:00.000       12
# 3                   12  2012-01-01 00:00:00.000       12
# 4                   12  2012-01-01 00:00:00.000       12
# ...     ...        ...                      ...      ...                 ...
# 1988                12  2012-01-01 00:00:00.000       12
# 1989    (H)         12  2018-02-01 00:00:00.000       12
# 1990   26.6         12  2012-12-31 00:00:00.000       12
# 1991                12  2012-01-01 00:00:00.000       12
# 1992                12  2012-01-01 00:00:00.000       12
#
# [282396 rows x 39 columns]

# %% [markdown]
# ## 下载第四个

# %%
# GROUP选择了livestock
params = {
    "source_desc":"SURVEY",
    "sector_desc":"ANIMALS & PRODUCTS",
    "group_desc":"LIVESTOCK",
    "commodity_desc":["CATTLE","GOATS","HOGS","SHEEP"],
    "statisticcat_desc":["INVENTORY"],
    "short_desc":["CATTLE, CALVES, SLAUGHTER, COMMERCIAL - SLAUGHTERED, MEASURED IN HEAD","CATTLE, CALVES, SLAUGHTER, ON FARM - SLAUGHTERED, MEASURED IN HEAD"],
    "agg_level_desc":"COUNTY"
}

# %%
data_all = pd.DataFrame()
# 数据太多了，所以按照州的一个一个下载，再用python合并
for i in range(State.shape[0]):
    params["state_name"] = State.loc[i].state_name
    data = stat.get_data(params)
    print(str(State.loc[i].state_name)+":"+str(data.shape[0]))
    
    # 将所有州合在一起，形成一个DF，最后再按照年划分
    data_all = pd.concat([data_all,data],axis=0) # 按行合并
# Out:
# ALABAMA22729
# ALASKA1383
# Response code 400: bad request - invalid query
# AMERICAN SAMOA0
# ARIZONA5425
# ARKANSAS24560
# CALIFORNIA21991
# COLORADO22089
# CONNECTICUT2971
# DELAWARE1193
# FLORIDA21957
# GEORGIA47503
# Response code 400: bad request - invalid query
# GUAM0
# HAWAII1648
# IDAHO16836
# ILLINOIS42182
# INDIANA38312
# IOWA46953
# KANSAS42578
# KENTUCKY42333
# LOUISIANA18391
# MAINE5684
# MARYLAND8600
# MASSACHUSETTS4183
# MICHIGAN33169
# MINNESOTA38860
# MISSISSIPPI24161
# MISSOURI47906
# MONTANA21505
# NEBRASKA39440
# NEVADA5292
# Response code 400: bad request - invalid query
# NEW ENGLAND0
# NEW HAMPSHIRE3527
# NEW JERSEY5361
# NEW MEXICO11498
# NEW YORK22389
# NORTH CAROLINA31456
# NORTH DAKOTA20265
# Response code 400: bad request - invalid query
# NORTHERN MARIANA ISLANDS0
# OHIO38248
# OKLAHOMA30835
# OREGON14292
# Response code 400: bad request - invalid query
# OTHER STATES0
# PENNSYLVANIA27876
# Response code 400: bad request - invalid query
# PUERTO RICO0
# RHODE ISLAND1454
# SOUTH CAROLINA15382
# SOUTH DAKOTA28556
# TENNESSEE33625
# Response code 413: exceeds limit=50000
# TEXAS0
# Response code 400: bad request - invalid query
# US TOTAL0
# UTAH11777
# VERMONT5435
# Response code 400: bad request - invalid query
# VIRGIN ISLANDS OF THE US0
# VIRGINIA33495
# WASHINGTON14829
# WEST VIRGINIA16607
# WISCONSIN31869
# WYOMING8989

# %%
all = 1149747

# %%
# 对于前面按州提取还超额的，再按照年提取
params["state_name"] = "TEXAS"
year=["1997","2002","2007","2012","2017"]
for i in year:
    params["year"] = i
    data_Texas = stat.get_data(params)
    print(data_Texas.shape[0])
    data_all = pd.concat([data_all,data_Texas],axis=0) # 按行合并
# # 按年分类保存成csv文件
# for year,group in data_all.groupby("year"):
#     group.to_csv("D:/中科院数据下载/quickstats/county/livestock/"+str(year)+".csv",index=False)
# Out:
# 9324
# 22758
# 21625
# 20097
# 18344

# %%
data_all
# Out:
#       Program  year      Period    Period Type week_ending   country_name  \
# 0      CENSUS  2017  END OF DEC  POINT IN TIME              UNITED STATES
# 1      CENSUS  2012  END OF DEC  POINT IN TIME              UNITED STATES
# 2      CENSUS  2007  END OF DEC  POINT IN TIME              UNITED STATES
# 3      CENSUS  2002  END OF DEC  POINT IN TIME              UNITED STATES
# 4      CENSUS  2017  END OF DEC  POINT IN TIME              UNITED STATES
# ...       ...   ...         ...            ...         ...            ...
# 18339  CENSUS  2017  END OF DEC  POINT IN TIME              UNITED STATES
# 18340  CENSUS  2017  END OF DEC  POINT IN TIME              UNITED STATES
# 18341  CENSUS  2017  END OF DEC  POINT IN TIME              UNITED STATES
# 18342  CENSUS  2017  END OF DEC  POINT IN TIME              UNITED STATES
# 18343  CENSUS  2017  END OF DEC  POINT IN TIME              UNITED STATES
#
#       country_code state_ansi state_fips_code state_alpha  ...      Group  \
# 0             9000         01              01          AL  ...  LIVESTOCK
# 1             9000         01              01          AL  ...  LIVESTOCK
# 2             9000         01              01          AL  ...  LIVESTOCK
# 3             9000         01              01          AL  ...  LIVESTOCK
# 4             9000         01              01          AL  ...  LIVESTOCK
# ...            ...        ...             ...         ...  ...        ...
# 18339         9000         48              48          TX  ...  LIVESTOCK
# 18340         9000         48              48          TX  ...  LIVESTOCK
# 18341         9000         48              48          TX  ...  LIVESTOCK
# 18342         9000         48              48          TX  ...  LIVESTOCK
# 18343         9000         48              48          TX  ...  LIVESTOCK
#
#                                            Data Item Zip Code   class_desc  \
# 0                    CATTLE, (EXCL COWS) - INVENTORY           (EXCL COWS)
# 1                    CATTLE, (EXCL COWS) - INVENTORY           (EXCL COWS)
# 2                    CATTLE, (EXCL COWS) - INVENTORY           (EXCL COWS)
# 3                    CATTLE, (EXCL COWS) - INVENTORY           (EXCL COWS)
# 4                    CATTLE, (EXCL COWS) - INVENTORY           (EXCL COWS)
# ...                                              ...      ...          ...
# 18339  SHEEP, INCL LAMBS - OPERATIONS WITH INVENTORY            INCL LAMBS
# 18340  SHEEP, INCL LAMBS - OPERATIONS WITH INVENTORY            INCL LAMBS
# 18341  SHEEP, INCL LAMBS - OPERATIONS WITH INVENTORY            INCL LAMBS
# 18342  SHEEP, INCL LAMBS - OPERATIONS WITH INVENTORY            INCL LAMBS
# 18343  SHEEP, INCL LAMBS - OPERATIONS WITH INVENTORY            INCL LAMBS
#
#                       Value CV (%) begin_code                load_time  \
# 0                       (D)    (D)         12  2018-02-01 00:00:00.000
# 1                       (D)    (D)         12  2012-12-31 00:00:00.000
# 2                       508                12  2012-01-01 00:00:00.000
# 3                       (D)                12  2012-01-01 00:00:00.000
# 4                       579   38.5         12  2018-02-01 00:00:00.000
# ...                     ...    ...        ...                      ...
# 18339                    11   83.4         12  2018-02-01 00:00:00.000
# 18340                   104   83.4         12  2018-02-01 00:00:00.000
# 18341                   381   83.4         12  2018-02-01 00:00:00.000
# 18342                   162   83.4         12  2018-02-01 00:00:00.000
# 18343                     8   83.4         12  2018-02-01 00:00:00.000
#
#       end_code congr_district_code
# 0           12
# 1           12
# 2           12
# 3           12
# 4           12
# ...        ...                 ...
# 18339       12
# 18340       12
# 18341       12
# 18342       12
# 18343       12
#
# [1149747 rows x 39 columns]

# %% [markdown]
# # 对表头(only county)
# ### 目的：匹配标准州县名称表格上OBJECTID
# 无论叫什么名称，都对应到唯一的一个OBJECTID上

# %%
import pandas as pd
# 对表头
standard = pd.read_excel("美国标准表头.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
#       2 # 对表头
# ----> 3 standard = pd.read_excel("美国标准表头.xlsx")
#
# File d:\D盘文件夹\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File d:\D盘文件夹\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File d:\D盘文件夹\Lib\site-packages\pandas\io\excel\_base.py:482, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480 if not isinstance(io, ExcelFile):
#     481     should_close = True
# --> 482     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483 elif engine and engine != io.engine:
#     484     raise ValueError(
#     485         "Engine should not be specified when passing "
#     486         "an ExcelFile - ExcelFile already has the engine set"
#     487     )
#
# File d:\D盘文件夹\Lib\site-packages\pandas\io\excel\_base.py:1652, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1650     ext = "xls"
#    1651 else:
# -> 1652     ext = inspect_excel_format(
#    1653         content_or_path=path_or_buffer, storage_options=storage_options
#    1654     )
#    1655     if ext is None:
#    1656         raise ValueError(
#    1657             "Excel file format cannot be determined, you must specify "
#    1658             "an engine manually."
#    1659         )
#
# File d:\D盘文件夹\Lib\site-packages\pandas\io\excel\_base.py:1525, in inspect_excel_format(content_or_path, storage_options)
#    1522 if isinstance(content_or_path, bytes):
#    1523     content_or_path = BytesIO(content_or_path)
# -> 1525 with get_handle(
#    1526     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1527 ) as handle:
#    1528     stream = handle.handle
#    1529     stream.seek(0)
#
# File d:\D盘文件夹\Lib\site-packages\pandas\io\common.py:865, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#    (...)
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
# --> 865         handle = open(handle, ioargs.mode)
#     866     handles.append(handle)
#     868 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '美国标准表头.xlsx'

# %%
# 数据导入
data_all = pd.DataFrame()
year = ["1997","2002","2007","2012","2017"]
for y in year:
    data_y = pd.read_csv("D:/中科院数据下载/quickstats/动物类/county/poultry/"+str(y)+".csv")
    data_all = pd.concat([data_all,data_y],axis=0)

# %% [markdown]
# # 完全匹配
# ### 与下载出来的数据data进行州县双重对应的完全匹配

# %%
# 定义一个核对表头的函数(完全匹配)
def label_county(standard,data):
    data["OBJECTID"] = -1
    
    # 保留的列
    col_need = ["year","Program","Sector","Commodity","Domain","Category","Group","Data Item","class_desc","OBJECTID","State","County","Value","CV (%)"]
    data = data.loc[:,col_need]
    # 创建一个字典，将州县组合
    mapping = {(row["State"].upper(),row["County"].upper()):row["OBJECTID"] for _,row in standard.iterrows()}
    # 使用apply函数创建data的OBJECTID
    data["OBJECTID"] = data.apply(lambda row:mapping.get((row["State"],row["County"]),-1),axis=1)
    return data

# %%
# 对data执行完全匹配
data_all = label_county(standard,data_all)

# %% [markdown]
# # 抽样统计
# ## 完全匹配中不成功的数据原因：
# ### 1、范围不一致，存在包含关系：比如下载的数据是Aleutians island，而标准数据名称是区分了Aleutians West和Aleutians East
# ### 2、存在缩写：下载的数据存在县名称的缩写，比如saint缩写成st.
# ### 3、表示形式不一致：比如LAPAZ与 lA Paz

# %%
# data2002[data2002["OBJECTID"]==-1] # 不是完全一致的县州名

# %% [markdown]
# # 大模型引入

# %%
# 用大模型完成剩余的匹配
# 设置大模型
# 引入文心一言4.0大模型
import requests
import json

API_KEY = "YrG7AyuCMXwLdgdGvvycmwgj"
SECRET_KEY = "5D9EH5u9N2m0SscWCYsNeCml4Sv6yOYw"

def baidu4(mes):
    url = "https://aip.baidubce.com/rpc/2.0/ai_custom/v1/wenxinworkshop/chat/completions_pro?access_token=" + get_access_token()
    
    payload = json.dumps({
        "messages": [
            {
                "role": "user",
                "content": mes
            }
        ]
    })
    headers = {
        'Content-Type': 'application/json'
    }
    
    response = requests.request("POST", url, headers=headers, data=payload)
    
    return response.json()["result"]   

def get_access_token():
    """
    使用 AK，SK 生成鉴权签名（Access Token）
    :return: access_token，或是None(如果错误)
    """
    url = "https://aip.baidubce.com/oauth/2.0/token"
    params = {"grant_type": "client_credentials", "client_id": API_KEY, "client_secret": SECRET_KEY}
    return str(requests.post(url, params=params).json().get("access_token"))

# import openai

# def chatgpt4(prompt):
# #     openai.api_key = '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'
#     openai.api_key = 'sk-47wXB3B45tIOUPPa3e8fD47eC47d4b21AcE3Fe12C14a0487'
#     response = openai.ChatCompletion.create(
#       model="gpt-3.5-turbo-1106",  # 选择使用的模型
#       messages=[{"role": "user", "content": prompt}]
#     )

#     return response.choices[0].message['content'].strip()

def chatgpt4(mes):
    url = "https://apejhvxcd.cloud.sealos.io/v1/chat/completions"
    
    payload = json.dumps({
        "model":"gpt-4-1106-preview",
        "messages": [
            {
                "role": "user",
                "content": mes
            }
        ]
    })
    headers = {
        'Authorization': 'sk-47wXB3B45tIOUPPa3e8fD47eC47d4b21AcE3Fe12C14a0487',
        'Content-Type': 'application/json'
    }
    
    response = requests.request("POST", url, headers=headers, data=payload)
    
    return response.json()["choices"][0]["message"]['content'].strip()

# %%
chatgpt4("你好")
# Out:
# '你好！有什么可以帮您的吗？'

# %% [markdown]
# ## 设置相应的prompt
# ## 用正则表达式提取模型判断结果（OBJECTID）
# ## 模型对需要进行人工判断的进行标记与备注

# %%
# 对每一个大模型判断的函数
def ai_label(row,mapping):
    prompt = "美国的一个县名"+row["County"]+"，这个州"+row["State"]+"的县有："+str(mapping[row["State"]])+"，放回该县对应的所有可能的数值，只发结果"
    ai_reply = chatgpt4(prompt)
    # 在正则表达式处理
    pattern = re.compile(r"\d+")
    objectid_num = pattern.findall(ai_reply)
    if len(ai_reply)<60 and len(objectid_num)==1:
        objectid = objectid_num[0]
        print("字符串小于60："+ai_reply)
        return (objectid)
    else:
        print(ai_reply)
        objectid = -2
        # 说明有歧义不好判断
        return objectid,ai_reply

# %%
# 模糊匹配
def county_label_ai(standard,data):
    # 用嵌套字典存储州与县
    count = 0
    mapping = {}
    for _,row in standard.iterrows():
        state = row["State"].upper()
        county = row["County"].upper()
        objectid = row["OBJECTID"]
    
        if state not in mapping:
            mapping[state] = {}
        mapping[state][county] = objectid 
    while data[data["OBJECTID"]==-1].shape[0] != 0:
        print("剩余objectid为-1的行数："+str(data[data["OBJECTID"]==-1].shape[0]))
        # 只要还存在objectid=-1就执行
        objectid = ai_label(data[data["OBJECTID"]==-1].iloc[0],mapping)
        data_county = data[data["OBJECTID"]==-1].iloc[0]["County"]
        data_State = data[data["OBJECTID"]==-1].iloc[0]["State"]
        if objectid[0] != -2:
            data.loc[(data["County"]==data_county)&(data["State"]==data_State),"OBJECTID"] = objectid[0]
        else:
            data.loc[(data["County"]==data_county)&(data["State"]==data_State),"OBJECTID"] = objectid[0]-count
            data.loc[(data["County"]==data_county)&(data["State"]==data_State),"OBJECTID_NOTES"] = objectid[1]
            count = count+1
    return data

# %%
data_all = county_label_ai(standard,data_all)

# %%
data_all['OBJECTID'] = pd.to_numeric(data_all['OBJECTID'], errors='coerce')  # 将非数字转换为NaN
# data_all[data_all["OBJECTID"]<0].to_csv("test2.csv",encoding="utf-8")

# %%
# 最后按年分类保存成csv文件
for year,group in data_all.groupby("year"):
    group.to_csv("D:/中科院数据下载/quickstats/动物类/county/poultry_standard/"+str(year)+".csv",index=False,encoding="utf-8")

# %%
# Out:
#         year Program Sector Commodity Domain      Category        Group  \
# 0       2000  SURVEY  CROPS      CORN  TOTAL  AREA PLANTED  FIELD CROPS
# 1       2000  SURVEY  CROPS      CORN  TOTAL  AREA PLANTED  FIELD CROPS
# 2       2000  SURVEY  CROPS      CORN  TOTAL  AREA PLANTED  FIELD CROPS
# 3       2000  SURVEY  CROPS      CORN  TOTAL  AREA PLANTED  FIELD CROPS
# 4       2000  SURVEY  CROPS      CORN  TOTAL  AREA PLANTED  FIELD CROPS
# ...      ...     ...    ...       ...    ...           ...          ...
# 102376  2000  SURVEY  CROPS     WHEAT  TOTAL         YIELD  FIELD CROPS
# 102377  2000  SURVEY  CROPS     WHEAT  TOTAL         YIELD  FIELD CROPS
# 102378  2000  SURVEY  CROPS     WHEAT  TOTAL         YIELD  FIELD CROPS
# 102379  2000  SURVEY  CROPS     WHEAT  TOTAL         YIELD  FIELD CROPS
# 102380  2000  SURVEY  CROPS     WHEAT  TOTAL         YIELD  FIELD CROPS
#
#                                                 Data Item   class_desc  \
# 0                                    CORN - ACRES PLANTED  ALL CLASSES
# 1                                    CORN - ACRES PLANTED  ALL CLASSES
# 2                                    CORN - ACRES PLANTED  ALL CLASSES
# 3                                    CORN - ACRES PLANTED  ALL CLASSES
# 4                                    CORN - ACRES PLANTED  ALL CLASSES
# ...                                                   ...          ...
# 102376  WHEAT, WINTER, NON-IRRIGATED - YIELD, MEASURED...       WINTER
# 102377  WHEAT, WINTER, NON-IRRIGATED - YIELD, MEASURED...       WINTER
# 102378  WHEAT, WINTER, NON-IRRIGATED - YIELD, MEASURED...       WINTER
# 102379  WHEAT, WINTER, NON-IRRIGATED - YIELD, MEASURED...       WINTER
# 102380  WHEAT, WINTER, NON-IRRIGATED - YIELD, MEASURED...       WINTER
#
#         OBJECTID    State                     County   Value  CV (%)  \
# 0            -16  ALABAMA  OTHER (COMBINED) COUNTIES   2,400     NaN
# 1             26  ALABAMA                    COLBERT   8,000     NaN
# 2             48  ALABAMA                 LAUDERDALE   7,700     NaN
# 3             49  ALABAMA                   LAWRENCE  10,500     NaN
# 4             51  ALABAMA                  LIMESTONE   7,400     NaN
# ...          ...      ...                        ...     ...     ...
# 102376      3147  WYOMING                    NATRONA      11     NaN
# 102377       -34  WYOMING  OTHER (COMBINED) COUNTIES      25     NaN
# 102378      3139  WYOMING                   CONVERSE      30     NaN
# 102379      3142  WYOMING                     GOSHEN      21     NaN
# 102380      3145  WYOMING                    LARAMIE      19     NaN
#
#                                            OBJECTID_NOTES
# 0       77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88...
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 102376                                                NaN
# 102377  3135, 3136, 3137, 3138, 3139, 3140, 3141, 3142...
# 102378                                                NaN
# 102379                                                NaN
# 102380                                                NaN
#
# [102381 rows x 15 columns]

# %%
# 下载county的动物的poultry,后续记得删除poultry total
# GROUP选择了poultry
params = {
    "source_desc":"SURVEY",
    "sector_desc":"CROPS",
    "group_desc":"FIELD CROPS",
#     "commodity_desc":["CHICKENS","DUCKS","EGGS","MEAL","POULTRY BY-PRODUCT MEALS",
#                      "POULTRY FATS","POULTRY TOTALS","POULTRY, OTHER","TURKEYS"],
#     "statisticcat_desc":["INVENTORY"],
#     "short_desc":["CHICKENS, YOUNG, SLAUGHTER, FI - SLAUGHTERED, MEASURED IN HEAD",
#                   "CHICKENS, YOUNG, SLAUGHTER, FI - SLAUGHTERED, MEASURED IN LB / HEAD, LIVE BASIS",
#                  "CHICKENS, YOUNG, SLAUGHTER, FI - SLAUGHTERED, MEASURED IN LB, LIVE BASIS",
#                  "TURKEYS, YOUNG, SLAUGHTER, FI - SLAUGHTERED, MEASURED IN HEAD",
#                   "TURKEYS, YOUNG, SLAUGHTER, FI - SLAUGHTERED, MEASURED IN LB / HEAD, LIVE BASIS",
#                  "TURKEYS, YOUNG, SLAUGHTER, FI - SLAUGHTERED, MEASURED IN LB, LIVE BASIS"],
    "agg_level_desc":"COUNTY",
    "year":"1957",
#     "state_name":"PENNSYLVANIA"
}

# %%
stat.get_par(params)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 stat.get_par(params)
#
# File d:\usda_quickstats\usda_quickstats.py:114, in get_par(par)
#     112 else:
#     113     status = response.status_code
# --> 114     status_str='Response code ' + str(status) + ': ' + response.json()[par][0]
#     115     print(status_str)
#     116     return pd.DataFrame()
#
# TypeError: unhashable type: 'dict'
