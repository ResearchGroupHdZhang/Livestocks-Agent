# %%
import os
import sys
sys.path.append("../stable-baselines3")
sys.path.append("..")
from torch.nn.modules.activation import F
os.environ["CUDA_VISIBLE_DEVICES"] = "4"
import gymnasium as gym
from logger import setup_logger
from livestockEnvV2 import load_datas,LivestockEnvConfig
from stable_baselines3 import PPO_action_mask_v2
from stable_baselines3.common.env_util import make_vec_env
from gymnasium.envs.registration import register
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.vec_env import DummyVecEnv, VecCheckNan
from AttentionPolicy import CustomAttentionPolicy
from stable_baselines3.common.evaluation_action_mask_v2 import evaluate_policy

register(
    id='LivestockEnv-v2',
    entry_point='livestockEnvV2:LivestockEnv',
)
country = 'cn'
config = LivestockEnvConfig(country, 
                            Reward_priority=[4, 4, 3, 2, 1], 
                            thresholds=[0, 31, 0], 
                            mobility_ratio=0.25,
                            max_steps=8000)

# 创建并包装环境
env = make_vec_env('LivestockEnv-v2', n_envs=1, env_kwargs={'config': config})
env = VecCheckNan(env, raise_exception=True)
eval_callback = EvalCallback(env, best_model_save_path=f'../logs/v2/{country}/',
                             log_path='./logs/', eval_freq=config.max_steps,
                             deterministic=False, render=False)
from typing import Callable

def linear_schedule(initial_value: float) -> Callable[[float], float]:
    """
    Linear learning rate schedule.

    :param initial_value: Initial learning rate.
    :return: schedule that computes
      current learning rate depending on remaining progress
    """
    def func(progress_remaining: float) -> float:
        """
        Progress will decrease from 1 (beginning) to 0.

        :param progress_remaining:
        :return: current learning rate
        """
        return progress_remaining * initial_value

    return func
# model = PPO_action_mask_v2(CustomAttentionPolicy, 
#                         env, 
#                         batch_size=4, 
#                         verbose=1, 
#                         tensorboard_log='./board/',
#                         seed=42,
#                         kwargs={'country':country},
#                         learning_rate=linear_schedule(2e-2),
#                         n_steps=2**13,
#                         )
# Out:
# /home/yanisy/.local/lib/python3.11/site-packages/gymnasium/envs/registration.py:788: UserWarning: WARN: The environment is being initialised with render_mode='rgb_array' that is not in the possible render_modes ([]).
#   logger.warn(

# %%
model = PPO_action_mask_v2.load(rf'../logs/v2/cn/best_model.zip', env=env)
# Out:
# /home/yanisy/.local/lib/python3.11/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.country to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.country` for environment variables or `env.get_wrapper_attr('country')` that will search the reminding wrappers.
#   logger.warn(
# /home/yanisy/.local/lib/python3.11/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.Move_in_tensor_Coef_N_demand to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.Move_in_tensor_Coef_N_demand` for environment variables or `env.get_wrapper_attr('Move_in_tensor_Coef_N_demand')` that will search the reminding wrappers.
#   logger.warn(
# /home/yanisy/.local/lib/python3.11/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.Move_in_tensor_Coef_ammonia_density to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.Move_in_tensor_Coef_ammonia_density` for environment variables or `env.get_wrapper_attr('Move_in_tensor_Coef_ammonia_density')` that will search the reminding wrappers.
#   logger.warn(
# /home/yanisy/.local/lib/python3.11/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.Move_in_tensor_Coef_livestock_PB to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.Move_in_tensor_Coef_livestock_PB` for environment variables or `env.get_wrapper_attr('Move_in_tensor_Coef_livestock_PB')` that will search the reminding wrappers.
#   logger.warn(
# /home/yanisy/.local/lib/python3.11/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.Move_out_tensor_Coef_N_demand to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.Move_out_tensor_Coef_N_demand` for environment variables or `env.get_wrapper_attr('Move_out_tensor_Coef_N_demand')` that will search the reminding wrappers.
#   logger.warn(
# /home/yanisy/.local/lib/python3.11/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.Move_out_tensor_Coef_ammonia_density to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.Move_out_tensor_Coef_ammonia_density` for environment variables or `env.get_wrapper_attr('Move_out_tensor_Coef_ammonia_density')` that will search the reminding wrappers.
#   logger.warn(
# /home/yanisy/.local/lib/python3.11/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.Move_out_tensor_Coef_livestock_PB to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.Move_out_tensor_Coef_livestock_PB` for environment variables or `env.get_wrapper_attr('Move_out_tensor_Coef_livestock_PB')` that will search the reminding wrappers.
#   logger.warn(
# /home/yanisy/.local/lib/python3.11/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.thresholds to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.thresholds` for environment variables or `env.get_wrapper_attr('thresholds')` that will search the reminding wrappers.
#   logger.warn(
# /home/yanisy/.local/lib/python3.11/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.mobility_ratio to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.mobility_ratio` for environment variables or `env.get_wrapper_attr('mobility_ratio')` that will search the reminding wrappers.
#   logger.warn(
# /home/yanisy/.local/lib/python3.11/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.action_len to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.action_len` for environment variables or `env.get_wrapper_attr('action_len')` that will search the reminding wrappers.
#   logger.warn(
# /home/yanisy/.local/lib/python3.11/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.amounts to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.amounts` for environment variables or `env.get_wrapper_attr('amounts')` that will search the reminding wrappers.
#   logger.warn(
# /home/yanisy/.local/lib/python3.11/site-packages/gymnasium/core.py:311: UserWarning: WARN: env.ammonia_density_case to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.ammonia_density_case` for environment variables or `env.get_wrapper_attr('ammonia_density_case')` that will search the reminding wrappers.
#   logger.warn(

# %%
# model = PPO_action_mask.load(rf'/home/yanisy/Researchs/Ai4S/畜牧业空间优化/强化学习/强化学习/logs/us/best_model/best_model.zip')

evaluate_policy(model, env, n_eval_episodes=1, deterministic=True, render=False, action_mask=None, save_path="../results")
# Out:
# /home/yanisy/.local/lib/python3.11/site-packages/gymnasium/utils/passive_env_checker.py:159: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# 进度:   0%|          | 0/100000 [00:00<?, ?it/s]/home/yanisy/.local/lib/python3.11/site-packages/gymnasium/utils/passive_env_checker.py:159: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# /home/yanisy/.local/lib/python3.11/site-packages/gymnasium/utils/passive_env_checker.py:246: UserWarning: WARN: The reward returned by `step()` must be a float, int, np.integer or np.floating, actual type: <class 'torch.Tensor'>
#   logger.warn(
# 进度:   6%|▋         | 6460/100000 [03:03<52:05, 29.93it/s, reward=7.01, mask=tensor(1778480, device='cuda:0')]
# 终止
# 进度:   6%|▋         | 6461/100000 [03:03<44:21, 35.14it/s, reward=7.01, mask=tensor(1778480, device='cuda:0')]
# (110510.454033, 0.0)
